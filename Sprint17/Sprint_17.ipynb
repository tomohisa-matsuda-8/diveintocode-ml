# %% [markdown]
# ### 【問題１】学習と推定

# %%
# !python train.py -p annotation.txt
# Out:
# Using TensorFlow backend.
# Parsing annotation files
# Training images per class (19 classes) :
# {'abraham_grampa_simpson': 687,
#  'apu_nahasapeemapetilon': 206,
#  'bart_simpson': 650,
#  'bg': 0,
#  'charles_montgomery_burns': 650,
#  'chief_wiggum': 209,
#  'comic_book_guy': 208,
#  'edna_krabappel': 212,
#  'homer_simpson': 718,
#  'kent_brockman': 213,
#  'krusty_the_clown': 429,
#  'lisa_simpson': 756,
#  'marge_simpson': 629,
#  'milhouse_van_houten': 210,
#  'moe_szyslak': 403,
#  'ned_flanders': 675,
#  'nelson_muntz': 219,
#  'principal_skinner': 614,
#  'sideshow_bob': 201}
# -------------------------------
# path to config file : ./save/train_20210328-123915_config.pickle
# -------------------------------
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# ...

# %%
# !python predict.py -i ../Simpsons/kaggle_simpson_testset/kaggle_simpson_testset -c ./save/train_20210328-123915_config.pickle
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# ...

# %% [markdown]
# 推定の出力が行われているか確認する。（出力ファイルがあればOKとする）

# %%
# %cd output/
# Out:
# /content/drive/My Drive/ObjectDetection/output

# %%
# !ls -a
# Out:
# result_abraham_grampa_simpson_0.jpg.png
# result_abraham_grampa_simpson_10.jpg.png
# result_abraham_grampa_simpson_11.jpg.png
# result_abraham_grampa_simpson_12.jpg.png
# result_abraham_grampa_simpson_13.jpg.png
# result_abraham_grampa_simpson_14.jpg.png
# result_abraham_grampa_simpson_15.jpg.png
# result_abraham_grampa_simpson_16.jpg.png
# result_abraham_grampa_simpson_17.jpg.png
# result_abraham_grampa_simpson_18.jpg.png
# result_abraham_grampa_simpson_19.jpg.png
# result_abraham_grampa_simpson_1.jpg.png
# result_abraham_grampa_simpson_20.jpg.png
# result_abraham_grampa_simpson_21.jpg.png
# result_abraham_grampa_simpson_22.jpg.png
# result_abraham_grampa_simpson_23.jpg.png
# result_abraham_grampa_simpson_24.jpg.png
# result_abraham_grampa_simpson_25.jpg.png
# result_abraham_grampa_simpson_26.jpg.png
# result_abraham_grampa_simpson_27.jpg.png
# result_abraham_grampa_simpson_28.jpg.png
# result_abraham_grampa_simpson_29.jpg.png
# result_abraham_grampa_simpson_2.jpg.png
# ...

# %% [markdown]
# ### 【問題２】コードリーディング

# %% [markdown]
# ・RPNを実現しているコードはどこか
#
# 　→faster_rcnn.py 18, 24, 28行
#
# 　→resnet.py　196行目〜
#
# ・RoIプーリングを実現しているコードはどこか
#
# 　→train.py 100行目〜
#
# 　　roi_helpers.py
#
# 　　resnet.py 205行目〜 RoiPoolingConvクラスを呼び出し
#
# 　　→RoiPoolingConv.py

# %% [markdown]
# ### 【問題3】学習済みの重みによる推定

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2021-03-28 13:25:43--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  40.0MB/s    in 6.2s
#
# 2021-03-28 13:25:50 (38.0 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !python convert.py yolov3.cfg yolov3.weights model_data/yolo.h5
# Out:
# Using TensorFlow backend.
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
# !python yolo_video.py --image
# Out:
# Using TensorFlow backend.
# Image detection mode
#  Ignoring remaining command line arguments: ./path2your_video,
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-03-28 13:39:17.699531: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-03-28 13:39:17.704329: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# ...

# %% [markdown]
# ### 【問題4】学習のためのファイルを作成
# 学習のためのファイルとして下記①、②を準備し、train.pyからファイルを読み込むように修正。
#
# ①simpsons学習用のアノテーションファイルを作成。（ファイル：YOLO_simpsons_annotation.txt）
#
# ②simpsons用クラス名定義データを作成。（ファイル：simpsons_classes.txt）

# %%
# !python convert.py -w yolov3.cfg yolov3.weights model_data/yolo_weights.h5
# Out:
# Using TensorFlow backend.
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %% [markdown]
# ### 【問題5】学習が行えることの確認
#
# 50エポック完了していないが、学習ができていることは確認できた。

# %%
# !python train.py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:88: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:91: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:507: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...
